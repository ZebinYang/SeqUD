# %% [markdown]
# ## Example 1: Cliff-Shaped function

# %% [markdown]
# $$
# f_{1}\left(x_{1}, x_{2} \right) = \left(x_{1}, x_{2} \right) = \exp \left\{-\frac{1}{2} \frac {x_{1}^{2}}{100} \right\} - \frac{1}{2} \left(x_{2} + 0.03 x_{1}^{2} - 3 \right)^{2}, \\
#  x_{1} \in [-20,20 ] , x_{2} \in [-10,5].
# $$

# %%
import numpy as np 
from matplotlib import pylab as plt
from seqmm.pysequd import SeqUDOptimizer

def cliff(parameters):
    x1 = parameters['x1']
    x2 = parameters['x2']
    term1 = -0.5*x1**2/100
    term2 = -0.5*(x2+0.03*x1**2-3)**2
    y = np.exp(term1 + term2)
    return  y

Level_Number = 20
ParaSpace = {'x1': {'Type': 'continuous', 'Range': [-20,20], 'Wrapper': lambda x: x}, 
             'x2': {'Type': 'continuous', 'Range': [-10,5], 'Wrapper': lambda x: x}}
clf = SeqUDOptimizer(cliff, ParaSpace, Level_Number, n_jobs = 1, verbose = True)
clf.search()
# Out:
# Stage 1 completed (20/100) with best score: 0.87563.
# Stage 2 completed (34/100) with best score: 0.98313.
# Stage 3 completed (49/100) with best score: 0.98880.
# Stage 4 completed (63/100) with best score: 0.99002.
# Stage 5 completed (79/100) with best score: 0.99914.
# Stage 6 completed (93/100) with best score: 0.99981.
# Maximum number of runs reached, stop!
# Search completed in 4.27 seconds.
# The best score is: 0.99981.
# The best configurations are:
# x1                  : -0.125
# x2                  : 2.98438

# %%
grid_num = 25
xlist = np.linspace(-20, 20, grid_num)
ylist = np.linspace(-10, 5, grid_num)
X, Y = np.meshgrid(xlist, ylist)
Z = np.zeros((grid_num,grid_num))
for i, x1 in enumerate(xlist):
    for j, x2 in enumerate(ylist):
        Z[j,i] = cliff({"x1": x1, "x2": x2})
        
cp = plt.contourf(X, Y, Z)
plt.scatter(clf.logs.loc[:,['x1']], 
            clf.logs.loc[:,['x2']], color = "red")
plt.ylim(-10,5)
plt.xlim(-20,20)
plt.colorbar(cp)
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %%
from smac.facade.func_facade import fmin_smac
def cliff(x):
    x1 = x[0]
    x2 = x[1]
    term1 = -0.5*x1**2/100
    term2 = -0.5*(x2+0.03*x1**2-3)**2
    y = np.exp(term1 + term2)
    return -y
x, cost, _ = fmin_smac(func=branin,  # function
                       x0=[0,-2.5],    # default configuration
                       bounds=[(-20, 20), (-10, 5)],  # limits
                       maxfun=100,   # maximum number of evaluations
                       rng=3)        # random seed
# Out:
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.174843 sec, available: 0.056920 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 97.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.164685 sec, available: 0.072206 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 95.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.149287 sec, available: 0.070376 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 93.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Configuration origin: %s Random Search (sorted)
# 3
# Timelimit for intensification reached (used: 0.221959 sec, available: 0.194687 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 90.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.151866 sec, available: 0.069255 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 88.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.144684 sec, available: 0.071419 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 86.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.153569 sec, available: 0.078347 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 84.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Configuration origin: %s Random Search (sorted)
# 3
# Timelimit for intensification reached (used: 0.222116 sec, available: 0.185716 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 81.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.152377 sec, available: 0.077216 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 79.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.143296 sec, available: 0.070001 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 77.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.147620 sec, available: 0.069972 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 75.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Configuration origin: %s Random Search (sorted)
# 3
# Timelimit for intensification reached (used: 0.230422 sec, available: 0.226671 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 72.000000 (target runs)
# New Round
# NEW
# Challenger was the same as the current incumbent; Skipping challenger
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Random Search (sorted)
# 2
# Timelimit for intensification reached (used: 0.157084 sec, available: 0.085713 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 70.000000 (target runs)
# New Round
# NEW
# Challenger was the same as the current incumbent; Skipping challenger
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Random Search (sorted)
# 2
# Timelimit for intensification reached (used: 0.173529 sec, available: 0.076295 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 68.000000 (target runs)
# New Round
# NEW
# Challenger was the same as the current incumbent; Skipping challenger
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Local Search
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.227200 sec, available: 0.157404 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 66.000000 (target runs)
# New Round
# NEW
# Challenger was the same as the current incumbent; Skipping challenger
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Random Search (sorted)
# 2
# Configuration origin: %s Random Search
# 3
# Timelimit for intensification reached (used: 0.262886 sec, available: 0.259830 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 63.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Local Search
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.174309 sec, available: 0.154217 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 61.000000 (target runs)
# New Round
# NEW
# Challenger was the same as the current incumbent; Skipping challenger
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Local Search
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.182966 sec, available: 0.075933 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 59.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.186040 sec, available: 0.115947 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 57.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.233355 sec, available: 0.198507 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 55.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Local Search
# 0
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Local Search
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.164294 sec, available: 0.084273 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 53.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.149308 sec, available: 0.074735 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 51.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.163399 sec, available: 0.094230 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 49.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Configuration origin: %s Random Search (sorted)
# 3
# Timelimit for intensification reached (used: 0.281021 sec, available: 0.194660 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 46.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Local Search
# 0
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Random Search (sorted)
# 2
# Timelimit for intensification reached (used: 0.173419 sec, available: 0.105337 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 44.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Local Search
# 0
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Local Search
# 2
# Timelimit for intensification reached (used: 0.218228 sec, available: 0.098058 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 42.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Local Search
# 0
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Local Search
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.150506 sec, available: 0.107869 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 40.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Configuration origin: %s Random Search (sorted)
# 3
# Timelimit for intensification reached (used: 0.219010 sec, available: 0.201312 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 37.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.180583 sec, available: 0.089834 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 35.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.137559 sec, available: 0.078977 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 33.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Local Search
# 0
# Configuration origin: %s Random Search
# 1
# Challenger was the same as the current incumbent; Skipping challenger
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.153590 sec, available: 0.078198 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 31.000000 (target runs)
# New Round
# NEW
# Challenger was the same as the current incumbent; Skipping challenger
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Random Search (sorted)
# 2
# Timelimit for intensification reached (used: 0.141332 sec, available: 0.076409 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 29.000000 (target runs)
# New Round
# NEW
# Challenger was the same as the current incumbent; Skipping challenger
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Random Search (sorted)
# 2
# Configuration origin: %s Random Search
# 3
# Configuration origin: %s Random Search (sorted)
# 4
# Configuration origin: %s Random Search
# 5
# Timelimit for intensification reached (used: 0.357847 sec, available: 0.338509 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 24.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.144826 sec, available: 0.093571 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 22.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Local Search
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.139521 sec, available: 0.091090 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 20.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.141289 sec, available: 0.081300 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 18.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Configuration origin: %s Random Search (sorted)
# 3
# Timelimit for intensification reached (used: 0.205301 sec, available: 0.200440 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 15.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.146816 sec, available: 0.072046 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 13.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.140476 sec, available: 0.072607 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 11.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Random Search (sorted)
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.142900 sec, available: 0.077245 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 9.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Local Search
# 0
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Random Search (sorted)
# 2
# Configuration origin: %s Random Search
# 3
# Timelimit for intensification reached (used: 0.214679 sec, available: 0.170711 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 6.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Local Search
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.149829 sec, available: 0.084654 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 4.000000 (target runs)
# New Round
# NEW
# Challenger was the same as the current incumbent; Skipping challenger
# Configuration origin: %s Random Search
# 1
# Configuration origin: %s Local Search
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.150420 sec, available: 0.113860 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 2.000000 (target runs)
# New Round
# NEW
# Configuration origin: %s Local Search
# 1
# Configuration origin: %s Random Search
# 2
# Timelimit for intensification reached (used: 0.139027 sec, available: 0.082892 sec)
# Remaining budget: inf (wallclock), inf (ta costs), 0.000000 (target runs)

# %%
Para, val, x = _.get_X_y()

# %%
min(val)
# Out:
# -0.9782336480289526

# %%
grid_num = 25
xlist = np.linspace(-20, 20, grid_num)
ylist = np.linspace(-10, 5, grid_num)
X, Y = np.meshgrid(xlist, ylist)
Z = np.zeros((grid_num,grid_num))
for i, x1 in enumerate(xlist):
    for j, x2 in enumerate(ylist):
        Z[j,i] = cliff([x1,x2])
        
cp = plt.contourf(X, Y, Z)
plt.scatter(Para[:,0], 
            Para[:,1], color = "red")
plt.ylim(-10,5)
plt.xlim(-20,20)
plt.colorbar(cp)
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# ## Example 2: Octopus-Shaped function

# %% [markdown]
# $$
# f_{2}(x_{1}, x_{2})  = 2\cos(10x)\sin(10y)+\sin(10xy), \quad x_{1}, x_{2} \in [0, 1].
# $$

# %%
import numpy as np 
from matplotlib import pylab as plt
from seqmm.pysequd import SeqUDOptimizer

def octopus(parameters):
    x1 = parameters['x1']
    x2 = parameters['x2']
    y = 2*np.cos(10*x1)*np.sin(10*x2)+np.sin(10*x1*x2)
    return  y

Level_Number = 20
ParaSpace = {'x1': {'Type': 'continuous', 'Range': [0,1], 'Wrapper': lambda x: x}, 
             'x2': {'Type': 'continuous', 'Range': [0,1], 'Wrapper': lambda x: x}}
clf = SeqUDOptimizer(octopus, ParaSpace, Level_Number, n_jobs = 10, verbose = True)
clf.search()
# Out:
# Stage 1 completed (20/100) with best score: 2.69862.
# Stage 2 completed (34/100) with best score: 2.69862.
# Stage 3 completed (48/100) with best score: 2.96798.
# Stage 4 completed (62/100) with best score: 2.96871.
# Stage 5 completed (75/100) with best score: 2.98843.
# Stage 6 completed (91/100) with best score: 2.99450.
# Maximum number of runs reached, stop!
# Search completed in 9.88 seconds.
# The best score is: 2.99450.
# The best configurations are:
# x1                  : 0.31719
# x2                  : 0.47656

# %%
grid_num = 25
xlist = np.linspace(0, 1, grid_num)
ylist = np.linspace(0, 1, grid_num)
X, Y = np.meshgrid(xlist, ylist)
Z = np.zeros((grid_num,grid_num))
for i, x1 in enumerate(xlist):
    for j, x2 in enumerate(ylist):
        Z[j,i] = octopus({"x1": x1, "x2": x2})
        
cp = plt.contourf(X, Y, Z)
plt.scatter(clf.logs.loc[:,['x1']], 
            clf.logs.loc[:,['x2']], color = "red")
plt.ylim(0,1)
plt.xlim(0,1)
plt.colorbar(cp)
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()
