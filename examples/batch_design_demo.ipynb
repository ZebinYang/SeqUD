# %% [markdown]
# ## Grid Search

# %%
import numpy as np 
from matplotlib import pylab as plt
from seqmm import GridSearch

def cliff(parameters):
    x1 = parameters['x1']
    x2 = parameters['x2']
    term1 = -0.5*x1**2/100
    term2 = -0.5*(x2+0.03*x1**2-3)**2
    y = np.exp(term1 + term2)
    return  y

ParaSpace = {'x1': {'Type': 'continuous', 'Range': [-20,20], 'Wrapper': lambda x: x}, 
             'x2': {'Type': 'continuous', 'Range': [-10,5], 'Wrapper': lambda x: x}}


clf = GridSearch(ParaSpace, max_runs = 100, verbose = True)
clf.fmin(cliff)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.86883.

# %%
import numpy as np 
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
from seqmm import GridSearch

iris = datasets.load_iris()
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = GridSearch(ParaSpace, max_runs = 100, estimator = estimator, cv = cv, refit = True, n_job = 10, verbose = True)

clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.97333.
# Search completed in 5.31 seconds.
# The best score is: 0.97333.
# The best configurations are:
# C                   : 0.46294
# gamma               : 0.39685

# %% [markdown]
# ## Random Search

# %%
import numpy as np 
from matplotlib import pylab as plt
from seqmm import RandSearch

def cliff(parameters):
    x1 = parameters['x1']
    x2 = parameters['x2']
    term1 = -0.5*x1**2/100
    term2 = -0.5*(x2+0.03*x1**2-3)**2
    y = np.exp(term1 + term2)
    return  y

ParaSpace = {'x1': {'Type': 'continuous', 'Range': [-20,20], 'Wrapper': lambda x: x}, 
             'x2': {'Type': 'continuous', 'Range': [-10,5], 'Wrapper': lambda x: x}}


clf = RandSearch(ParaSpace, max_runs = 100, verbose = True)
clf.fmin(cliff)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.79828.

# %%
import numpy as np 
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
from seqmm import RandSearch

iris = datasets.load_iris()
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = RandSearch(ParaSpace, max_runs = 100, estimator = estimator, cv = cv, refit = True, n_job = 10, verbose = True)
clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.98000.
# Search completed in 0.81 seconds.
# The best score is: 0.98000.
# The best configurations are:
# C                   : 3192.0272
# gamma               : 7e-05

# %% [markdown]
# ## Latin Hypercude Sampling

# %%
import numpy as np 
from matplotlib import pylab as plt
from seqmm import LHSSearch

def cliff(parameters):
    x1 = parameters['x1']
    x2 = parameters['x2']
    term1 = -0.5*x1**2/100
    term2 = -0.5*(x2+0.03*x1**2-3)**2
    y = np.exp(term1 + term2)
    return  y

ParaSpace = {'x1': {'Type': 'continuous', 'Range': [-20,20], 'Wrapper': lambda x: x}, 
             'x2': {'Type': 'continuous', 'Range': [-10,5], 'Wrapper': lambda x: x}}


clf = LHSSearch(ParaSpace, max_runs = 100, verbose = True)
clf.fmin(cliff)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.97566.

# %%
import numpy as np 
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
from seqmm import LHSSearch

iris = datasets.load_iris()
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = LHSSearch(ParaSpace, max_runs = 100, estimator = estimator, cv = cv, refit = True, n_job = 10, verbose = True)
clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.98000.
# Search completed in 0.93 seconds.
# The best score is: 0.98000.
# The best configurations are:
# C                   : 1.90528
# gamma               : 0.18049

# %% [markdown]
# ## Sobol Sequence

# %%
import numpy as np 
from matplotlib import pylab as plt
from seqmm import SobolSearch

def cliff(parameters):
    x1 = parameters['x1']
    x2 = parameters['x2']
    term1 = -0.5*x1**2/100
    term2 = -0.5*(x2+0.03*x1**2-3)**2
    y = np.exp(term1 + term2)
    return  y

ParaSpace = {'x1': {'Type': 'continuous', 'Range': [-20,20], 'Wrapper': lambda x: x}, 
             'x2': {'Type': 'continuous', 'Range': [-10,5], 'Wrapper': lambda x: x}}


clf = SobolSearch(ParaSpace, max_runs = 100, verbose = True)
clf.fmin(cliff)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.87734.

# %%
import numpy as np 
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
from seqmm import SobolSearch

iris = datasets.load_iris()
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = SobolSearch(ParaSpace, max_runs = 100, estimator = estimator, cv = cv, refit = True, n_job = 10, verbose = True)
clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.97333.
# Search completed in 0.62 seconds.
# The best score is: 0.97333.
# The best configurations are:
# C                   : 2070.30126
# gamma               : 0.00015

# %% [markdown]
# ## Uniform Design

# %%
import numpy as np 
from matplotlib import pylab as plt
from seqmm import UDSearch

def cliff(parameters):
    x1 = parameters['x1']
    x2 = parameters['x2']
    term1 = -0.5*x1**2/100
    term2 = -0.5*(x2+0.03*x1**2-3)**2
    y = np.exp(term1 + term2)
    return  y

ParaSpace = {'x1': {'Type': 'continuous', 'Range': [-20,20], 'Wrapper': lambda x: x}, 
             'x2': {'Type': 'continuous', 'Range': [-10,5], 'Wrapper': lambda x: x}}

level_number = 20
clf = UDSearch(ParaSpace, max_runs = 100, level_number = 20, verbose = True)
clf.fmin(cliff)
clf.plot_scores()
# Out:
# No design found.
# ...
# Search completed (100/100) with best score: 0.88425.

# %%
import numpy as np 
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
from seqmm import UDSearch

iris = datasets.load_iris()

level_number = 20
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = UDSearch(ParaSpace, max_runs = 100, estimator = estimator, cv = cv, refit = True, n_job = 10, verbose = True)
clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# No design found.
# ...
# Search completed (100/100) with best score: 0.98000.
# Search completed in 55.02 seconds.
# The best score is: 0.98000.
# The best configurations are:
# C                   : 21.85664
# gamma               : 0.00996
