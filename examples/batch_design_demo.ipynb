# %% [markdown]
# ## Grid Search

# %%
# %matplotlib inline

import numpy as np 
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
from seqmml import GridSearch

iris = datasets.load_iris()
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = GridSearch(ParaSpace, max_runs = 100, estimator = estimator, cv = cv, refit = True, n_jobs = 10, verbose = True)

clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.97333.
# Search completed in 3.23 seconds.
# The best score is: 0.97333.
# The best configurations are:
# C                   : 0.46294
# gamma               : 0.39685

# %% [markdown]
# ## Random Search

# %%
import numpy as np 
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
from seqmml import RandSearch

iris = datasets.load_iris()
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = RandSearch(ParaSpace, max_runs = 100, estimator = estimator, cv = cv, refit = True, n_jobs = 10, verbose = True)
clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.97333.
# Search completed in 0.30 seconds.
# The best score is: 0.97333.
# The best configurations are:
# C                   : 19.14422
# gamma               : 0.00759

# %% [markdown]
# ## Latin Hypercude Sampling

# %%
import numpy as np 
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
from seqmml import LHSSearch

iris = datasets.load_iris()
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = LHSSearch(ParaSpace, max_runs = 100, estimator = estimator, cv = cv, refit = True, n_jobs = 10, verbose = True)
clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.98000.
# Search completed in 0.41 seconds.
# The best score is: 0.98000.
# The best configurations are:
# C                   : 849.22321
# gamma               : 0.00026

# %% [markdown]
# ## Sobol Sequence

# %%
import numpy as np 
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
from seqmml import SobolSearch

iris = datasets.load_iris()
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = SobolSearch(ParaSpace, max_runs = 100, estimator = estimator, cv = cv, refit = True, n_jobs = 10, verbose = True)
clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.97333.
# Search completed in 0.31 seconds.
# The best score is: 0.97333.
# The best configurations are:
# C                   : 2070.30126
# gamma               : 0.00015

# %% [markdown]
# ## Uniform Design

# %%
import numpy as np 
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
from seqmml import UDSearch

iris = datasets.load_iris()
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = UDSearch(ParaSpace, max_runs = 100, level_number = 20, estimator = estimator, cv = cv, refit = True, n_jobs = 10, verbose = True)
clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# ...
# Search completed (100/100) with best score: 0.98000.
# Search completed in 16.73 seconds.
# The best score is: 0.98000.
# The best configurations are:
# C                   : 21.85664
# gamma               : 0.00996
