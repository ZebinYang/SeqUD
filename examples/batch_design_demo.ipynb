# %%
from SeqMM.pybatdoe import LHSSklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9a873bdd71d0> in <module>
# ----> 1 from SeqMM.pybatdoe import LHSSklearn
#
# ModuleNotFoundError: No module named 'SeqMM.pybatdoe'

# %%
import seqmm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-de4e83012420> in <module>
# ----> 1 import seqmm
#
# ~/anaconda2_local/lib/python3.7/site-packages/seqmm/__init__.py in <module>
# ----> 1 from .pySeqUD import *
#       2 from .pyBayOpt import *
#       3 from .pyBatDOE import *
#       4
#       5 __all__ =  ["SeqUDSklearn", "SeqUDOptimizer", "GPEISklearn", "SMACSklearn", "TPESklearn", "LHSSklearn", "SobolSklearn"]
#
# ModuleNotFoundError: No module named 'seqmm.pySeqUD'

# %%
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
iris = datasets.load_iris()
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = SobolSklearn(estimator, cv, ParaSpace, max_runs = 100, n_jobs = 10, refit = True, verbose = True)
clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# Search completed (100/100) with best score: 0.97333.
# Search completed in 0.93 seconds.
# The best score is: 0.97333.
# The best configurations are:
# C                   : 2070.30126
# gamma               : 0.00015

# %%
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
iris = datasets.load_iris()
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = UDSklearn(estimator, cv, ParaSpace, level_number = 20, max_runs = 100, max_search_iter = 30, n_jobs = 10, 
                refit = True, verbose = True)
clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# No design found.
# HBox(children=(IntProgress(value=0), HTML(value='')))
# Search completed (100/100) with best score: 0.98000.
# Search completed in 10.78 seconds.
# The best score is: 0.98000.
# The best configurations are:
# C                   : 21.85664
# gamma               : 0.00996

# %%
from sklearn import svm
from sklearn import datasets
from sklearn.model_selection import KFold
iris = datasets.load_iris()
ParaSpace = {'C':{'Type': 'continuous', 'Range': [-6, 16], 'Wrapper': np.exp2}, 
       'gamma': {'Type': 'continuous', 'Range': [-16, 6], 'Wrapper': np.exp2}}
estimator = svm.SVC()
cv = KFold(n_splits=5, random_state=1, shuffle=True)
clf = GridSklearn(estimator, cv, ParaSpace, max_runs = 100, n_jobs = 10, 
                refit = True, verbose = True)
clf.fit(iris.data, iris.target)
clf.plot_scores()
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# Search completed (100/100) with best score: 0.97333.
# Search completed in 1.09 seconds.
# The best score is: 0.97333.
# The best configurations are:
# C                   : 0.46294
# gamma               : 0.39685
